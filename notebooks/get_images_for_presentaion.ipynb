# %%
# %cd ..
# Out:
# /home/s-uesaka/augment_xgaze

# %%
from generate_augmented_dataset_copy import ImageAugmentor
from notebook_utils import get_normalized_image_and_lm, get_augmented_image_and_lm, get_concat_h, draw_lm, draw_horizontal_line,get_normalized_image_mpii
from pathlib import Path

# %%
augmentor = ImageAugmentor()
# Out:
# ...
# Fetching 13 files:   0%|          | 0/13 [00:00<?, ?it/s]
# /home/s-uesaka/miniconda3/envs/augment_xgaze_new/lib/python3.10/site-packages/transformers/models/clip/feature_extraction_clip.py:28: FutureWarning: The class CLIPFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use CLIPImageProcessor instead.
#   warnings.warn(

# %%
image, lm = get_normalized_image_and_lm(dataset_dir = Path("/home/s-uesaka/datasets/xgaze_512/train"),
                                        subject_number =95,
                                        image_index = 4,
                                        random_sample=True,
                                        max_image_index=30)
image
# Out:
# /home/s-uesaka/datasets/xgaze_512/train/subject0009.h5
# Image Index: 8, Path: /home/s-uesaka/datasets/xgaze_512/train/subject0009.h5 CameraIndex: 9
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
after_depth, generated_image, inpainted_image, mask = augmentor.generate_augmentated_image(image, lm, stablediffusion_config={'prompt': "jaredlewwwbigbaldhead texas indie flirt skype aforundocumented latin supportive abnormal face horny ptbo shaved supportive", "negative_prompt": "deformed, bad anatomy", "seed": 0, "scale": 9, "steps": 50, "strength": 0.9})
# Out:
# ...
#   0%|          | 0/25 [00:00<?, ?it/s]

# %%
after_depth
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
generated_image
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
inpainted_image
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
mask
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>
